# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Dawit Girma Kasa**
# Data scientist

# %% [markdown]
# *I am interested in data science because I love statistical inference i love to analyze  information and .i love picking up on patterns and making judgment.*

# %% [markdown]
# ### The code below will show printing a string

# %%
print("let's go")
# Out:
# let's go

# %% [markdown]
# <a href="https://author-ide.skills.network/render?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..1_csippFJBrd38raMrUuz7b9dYvv3BocWRMWacJKHYg">Rstudio </a>
#
# ***
#
#
# |name|sex|
# |----|---|
# |Dave|male|
# |Bety|female|
#
# ***
#
# m="i love python"
# x=m.replace('python','Abelton')
# print(x)
#
# 1. python
# 1. R
# 1. SQL
#  - ~~watson~~
#
# ***
#
#
# ![Eihv2erXsAE5DxS.jpg](attachment:30a9d2ab-773f-4eaa-af8a-fb42b7cadcc9.jpg)
#
#
#
#  - flower
#   - love
#    - code
